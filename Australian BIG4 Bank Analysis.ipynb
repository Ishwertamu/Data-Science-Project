# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
# %matplotlib inline

# %%
import pandas_datareader.data as pdr
from datetime import datetime
from __future__ import division
'''If your code uses pandas_datareader and you want to download data faster, 
you can “hijack” pandas_datareader.data.get_data_yahoo() method to use yfinance while making sure
the returned data is in the same format as pandas_datareader’s get_data_yahoo().'''
import yfinance as yf
yf.pdr_override()

# %%
bank_list = ['CBA', 'NAB', 'WBC', 'ANZ']

# %%
end = datetime.now()
start = datetime(end.year-1, end.month, end.day)

# %%
for bank in bank_list:
    globals()[bank] = pdr.get_data_yahoo(bank+'.AX',  start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
CBA.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  255.000000  255.000000  255.000000  255.000000  255.000000
# mean    82.193177   82.831647   81.569216   82.219882   81.346129
# std     11.252697   11.281721   11.217516   11.259492   11.799852
# min     63.000000   63.279999   62.639999   63.070000   61.973892
# 25%     71.255001   72.004997   71.024998   71.509998   69.387062
# 50%     83.800003   84.459999   83.129997   83.750000   82.779999
# 75%     88.289997   88.770000   87.509998   87.950001   87.845001
# max    105.500000  106.570000  105.110001  105.910004  105.910004
#
#              Volume
# count  2.550000e+02
# mean   2.766090e+06
# std    1.211784e+06
# min    3.506190e+05
# 25%    1.979766e+06
# 50%    2.455634e+06
# 75%    3.283504e+06
# max    9.528922e+06

# %%
NAB.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  255.000000  255.000000  255.000000  255.000000  255.000000
# mean    22.828941   23.006118   22.646471   22.831137   22.334973
# std      3.630068    3.633952    3.629677    3.624599    3.758817
# min     16.770000   16.920000   16.559999   16.639999   16.040203
# 25%     18.640000   18.865001   18.515000   18.645000   17.972933
# 50%     23.709999   23.879999   23.459999   23.610001   23.076241
# 75%     26.240000   26.400000   26.040001   26.219999   25.959773
# max     27.820000   27.840000   27.290001   27.510000   27.510000
#
#              Volume
# count  2.550000e+02
# mean   6.568044e+06
# std    3.003745e+06
# min    5.048510e+05
# 25%    4.656408e+06
# 50%    5.989376e+06
# 75%    7.892304e+06
# max    2.168546e+07

# %%
WBC.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  255.000000  255.000000  255.000000  255.000000  255.000000
# mean    21.475882   21.638020   21.316588   21.478196   20.999550
# std      3.490983    3.485966    3.493878    3.486627    3.650943
# min     16.100000   16.200001   16.000000   16.049999   15.428406
# 25%     18.010000   18.145000   17.835000   17.965000   17.269240
# 50%     20.700001   20.809999   20.510000   20.610001   20.146135
# 75%     25.115000   25.255000   24.959999   25.115001   24.549743
# max     26.799999   27.120001   26.719999   26.940001   26.940001
#
#              Volume
# count  2.550000e+02
# mean   7.788359e+06
# std    3.577782e+06
# min    1.101191e+06
# 25%    5.308115e+06
# 50%    7.132660e+06
# 75%    9.262670e+06
# max    2.609463e+07

# %%
ANZ.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  255.000000  255.000000  255.000000  255.000000  255.000000
# mean    23.641137   23.846412   23.443235   23.646627   23.049105
# std      4.311710    4.312514    4.305969    4.300797    4.501880
# min     16.600000   16.629999   16.400000   16.459999   15.758278
# 25%     18.690001   19.000000   18.525001   18.804999   17.950652
# 50%     23.830000   24.160000   23.629999   23.850000   23.248379
# 75%     28.200001   28.335000   27.960000   28.120000   27.691802
# max     29.190001   29.639999   29.010000   29.230000   29.230000
#
#              Volume
# count  2.550000e+02
# mean   6.079792e+06
# std    2.857411e+06
# min    1.031568e+06
# 25%    4.024779e+06
# 50%    5.452089e+06
# 75%    7.268874e+06
# max    1.795382e+07

# %%
CBA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 255 entries, 2020-07-14 to 2021-07-14
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       255 non-null    float64
#  1   High       255 non-null    float64
#  2   Low        255 non-null    float64
#  3   Close      255 non-null    float64
#  4   Adj Close  255 non-null    float64
#  5   Volume     255 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 13.9 KB

# %%
CBA['Adj Close'].plot(legend = True, figsize = (10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ANZ['Adj Close'].plot(legend = True, figsize = (10,9))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
WBC['Adj Close'].plot(legend = True, figsize = (10,9))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
NAB['Adj Close'].plot(legend = True, figsize = (10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
CBA['Volume'].plot(legend=True, figsize = (10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ANZ['Volume'].plot(legend=True, figsize = (10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
WBC['Volume'].plot(legend=True, figsize = (10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
NAB['Volume'].plot(legend=True, figsize = (10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Moving Average : In statistics, a moving average is a calculation used to analyze data points by creating a series of averages of different subsets of the full data set. In finance, a moving average (MA) is a stock indicator that is commonly used in technical analysis. The reason for calculating the moving average of a stock is to help smooth out the price data by creating a constantly updated average price. https://www.investopedia.com/terms/m/movingaverage.asp#:~:text=In%20statistics%2C%20a%20moving%20average,commonly%20used%20in%20technical%20analysis.

# %%
ma_day = [10,20,50]

# %%
for ma in ma_day:
    column_name = 'MA for %s days' %(str(ma))
    CBA[column_name] = CBA['Adj Close'].rolling(ma).mean()

# %%
CBA[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(subplots = False, figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
for ma in ma_day:
    column_name = 'MA for %s days' %(str(ma))
    ANZ[column_name] = ANZ['Adj Close'].rolling(ma).mean()
    WBC[column_name] = WBC['Adj Close'].rolling(ma).mean()
    NAB[column_name] = NAB['Adj Close'].rolling(ma).mean()

# %%
ANZ[['Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(subplots = False, figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
WBC[['Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(subplots = False, figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
NAB[['Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(subplots = False, figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
CBA['Daily Return'] = CBA['Adj Close'].pct_change()
ANZ['Daily Return'] = ANZ['Adj Close'].pct_change()
WBC['Daily Return'] = WBC['Adj Close'].pct_change()
NAB['Daily Return'] = NAB['Adj Close'].pct_change()

# %%
CBA['Daily Return'].plot(figsize = (10,4), legend = True, linestyle = '--', marker='o')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ANZ['Daily Return'].plot(figsize = (10,4), legend = True, linestyle = '--', marker='o')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
WBC['Daily Return'].plot(figsize = (10,4), legend = True, linestyle = '--', marker='o')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
NAB['Daily Return'].plot(figsize = (10,4), legend = True, linestyle = '--', marker='o')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
sns.displot(CBA['Daily Return'].dropna(), bins = 100, color = 'purple', kde = True)

# %%
sns.displot(ANZ['Daily Return'].dropna(), bins = 100, color = 'purple', kde = True)

# %%
sns.displot(WBC['Daily Return'].dropna(), bins = 100, color = 'purple', kde = True)

# %%
sns.displot(NAB['Daily Return'].dropna(), bins = 100, color = 'purple', kde = True)

# %%
nbank_list = []
for bank in bank_list:
    nbank_list.append(bank+'.AX')
    
closing_df = web.get_data_yahoo(nbank_list, start, end)['Adj Close']
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
#Renamin columns name
closing_df = closing_df.rename(columns = {'ANZ.AX':'ANZ','CBA.AX':'CBA','NAB.AX':'NAB','WBC.AX':'WBC'}, inplace=False)
closing_df.head()
# Out:
#                   ANZ        CBA        NAB        WBC
# Date
# 2020-07-14  17.394857  69.503342  17.447578  17.139469
# 2020-07-15  17.621500  70.472305  17.524693  17.283659
# 2020-07-16  17.460962  70.385094  17.418657  17.120243
# 2020-07-17  17.442074  70.346329  17.447578  17.197144
# 2020-07-20  17.234318  69.755272  17.168030  16.995277

# %%
bank_rets = closing_df.pct_change() # percent change method - Percentage change between the current and a prior element.
bank_rets.head()
# Out:
#                  ANZ       CBA       NAB       WBC
# Date
# 2020-07-14       NaN       NaN       NaN       NaN
# 2020-07-15  0.013029  0.013941  0.004420  0.008413
# 2020-07-16 -0.009110 -0.001238 -0.006051 -0.009455
# 2020-07-17 -0.001082 -0.000551  0.001660  0.004492
# 2020-07-20 -0.011911 -0.008402 -0.016022 -0.011738

# %%
sns.jointplot(x='CBA', y ='ANZ', data = bank_rets, kind ='scatter', color = 'indianred')

# %%
sns.jointplot(x='WBC', y ='NAB', data = bank_rets, kind ='scatter', color = 'magenta')

# %%
sns.pairplot(bank_rets.dropna())
'''pairplot - this function will create a grid of Axes such that each numeric variable in data 
will by shared across the y-axes across a single row and the x-axes across a single column. 
The diagonal plots are treated differently: a univariate distribution plot is drawn to 
show the marginal distribution of the data in each column.'''
# Out:
# ' this function will create a grid of Axes such that each numeric variable in data \nwill by shared across the y-axes across a single row and the x-axes across a single column. \nThe diagonal plots are treated differently: a univariate distribution plot is drawn to \nshow the marginal distribution of the data in each column.'

# %%
returns_fig = sns.PairGrid(bank_rets.dropna())
returns_fig.map_upper(plt.scatter, color = 'purple', s = 5)
returns_fig.map_lower(sns.kdeplot, cmap = 'cool_d')
returns_fig.map_diag(sns.histplot, bins = 30, color ='green', alpha = 0.6)

# %%
d = bank_rets.dropna()
sns.set_theme()
# Compute the correlation matrix
corr = d.corr()

# Generate a mask for the upper triangle
mask = np.triu(corr)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(6, 4))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(240, 20, n = 9, as_cmap=True)

stheme = sns.set_theme(style = 'whitegrid')
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr,  mask = mask, cmap=cmap,  vmax=.8, center=0.75,
            square=True, linewidths=.3, cbar_kws={"shrink": .5},ax=ax, annot=True, fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
t = closing_df.dropna()
sns.set_theme()
# Compute the correlation matrix
corr = t.corr()

# Generate a mask for the upper triangle
mask = np.triu(corr)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(6, 4))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(240, 20, n = 9, as_cmap=True)

stheme = sns.set_theme(style = 'whitegrid')
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr,  mask = mask, cmap=cmap,  vmax=1, center=0.97,
            square=True, linewidths=.3, cbar_kws={"shrink": .5},ax=ax, annot=True, fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Expected returns against Risk - share with High return with low risk would be favourable

# %%
# Define a new DataFrame as a clenaed version of the oriignal bank_rets DataFrame
rets = bank_rets.dropna()
area = np.pi*30
sns.scatterplot(x = rets.mean(), y = rets.std(), data = rets, alpha = 0.3, s = area)
sns.set_theme()
# Set the x and y limits of the plot 
plt.ylim([0.0,0.05])
plt.xlim([0.0012,0.0022])

#Set the plot axis titles
plt.xlabel('Expected returns')
plt.ylabel('Risk')

# Label the scatter plots
for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(label, xy = (x, y), xytext = (50, 50),textcoords = 'offset points', ha = 'right', va = 'bottom',
        arrowprops = dict(arrowstyle = '-', connectionstyle = 'arc3, rad=-0.3'))

# %% [markdown]
# What Is Value at Risk (VaR)? Value at risk (VaR) is a statistic that measures and quantifies the level of financial risk within a firm, portfolio or position over a specific time frame. This metric is most commonly used by investment and commercial banks to determine the extent and occurrence ratio of potential losses in their institutional portfolios. https://www.investopedia.com/terms/v/var.asp

# %%
sns.displot(CBA['Daily Return'].dropna(), bins=100, color = 'green', kde = True)

# %%
rets['CBA'].quantile(0.05)
# Out:
# -0.01903342776793902

# %%
sns.displot(ANZ['Daily Return'].dropna(), bins=100, color = 'green', kde = True)

# %%
rets['ANZ'].quantile(0.05)
# Out:
# -0.020345922944572013

# %%
sns.displot(WBC['Daily Return'].dropna(), bins=100, color = 'green', kde = True)

# %%
rets['WBC'].quantile(0.05)
# Out:
# -0.01970074062816805

# %%
sns.displot(NAB['Daily Return'].dropna(), bins=100, color = 'green', kde = True)

# %%
rets['NAB'].quantile(0.05)
# Out:
# -0.0201792095952968

# %% [markdown]
# What Is a Monte Carlo Simulation?
# Monte Carlo simulations are used to model the probability of different outcomes in a process that cannot easily be predicted due to the intervention of random variables. It is a technique used to understand the impact of risk and uncertainty in prediction and forecasting models.
#
# https://www.investopedia.com/terms/m/montecarlosimulation.asp

# %%
days = 365

dt = 1/days

def stock_monte_carlo(start_price, days, mu, sigma):
    
    price = np.zeros(days)
    price[0] = start_price
    
    shock = np.zeros(days)
    drift = np.zeros(days)
    
    for x in range(1,days):
        shock[x] = np.random.normal(loc=mu*dt, scale = sigma*np.sqrt(dt))
        
        drift[x] = mu * dt
        
        price[x] = price[x-1] + (price[x-1] * (drift[x] + shock[x]))
        
    return price

# %%
CBA.tail()
# Out:
#                   Open        High        Low      Close  Adj Close   Volume  \
# Date
# 2021-07-08   99.360001  100.180000  99.139999  99.489998  99.489998  1807323
# 2021-07-09   98.650002   98.889999  97.709999  98.589996  98.589996  2720818
# 2021-07-12   99.349998   99.489998  98.720001  99.169998  99.169998  1510229
# 2021-07-13  100.000000  100.120003  98.339996  98.389999  98.389999  2270019
# 2021-07-14   98.400002   99.050003  97.949997  98.779999  98.779999  2036198
#
#             MA for 10 days  MA for 20 days  MA for 50 days  Daily Return
# Date
# 2021-07-08       99.467001        100.5945         98.4214     -0.002206
# 2021-07-09       99.400000        100.4315         98.5932     -0.009046
# 2021-07-12       99.330000        100.3220         98.7958      0.005883
# 2021-07-13       99.120999        100.0690         98.9696     -0.007865
# 2021-07-14       99.011999         99.7670         99.1362      0.003964

# %%
mu = rets.mean()['CBA']
sigma = rets.std()['CBA']

start_price = 72

for run in range(100):
    plt.plot(stock_monte_carlo(start_price, days, mu, sigma))

plt.xlabel('Days')
plt.ylabel('Price')
plt.title('Mone Carlo Analysis for Commonwealth Bank')
# Out:
# Text(0.5, 1.0, 'Mone Carlo Analysis for Commonwealth Bank')

# %%
runs = 10000

simulation = np.zeros(runs)
for run in range(runs):
    simulation[run] = stock_monte_carlo(start_price, days, mu, sigma)[days - 1]

# %%
q = np.percentile(simulation, 1)

plt.hist(simulation, bins = 200)

#starting price
plt.figtext(0.6,0.8, s = 'Start price: $%.2f' %start_price)

#mean ending price
plt.figtext(0.6,0.7, s = 'Mean final price: $%.2f' %simulation.mean())

#variance of the price (within 99% confidence interval)
plt.figtext(0.6,0.6, s = 'Var(0.99) price: $%.2f' %(start_price - q))

#Display 1% quantile
plt.figtext(0.15,0.8, s = 'q(0.99): $%.2f' %q)

# Plot a line at the 1% quantile result
plt.axvline(x=q, linewidth = 4, color = 'r')

#title
plt.title(u"Final price distribution for Commonwealth Bank Stock after %s days" % days, weight = 'bold');

# %%
mu = rets.mean()['ANZ']
sigma = rets.std()['ANZ']

start_price = 18.50

for run in range(100):
    plt.plot(stock_monte_carlo(start_price, days, mu, sigma))

plt.xlabel('Days')
plt.ylabel('Price')
plt.title('Mone Carlo Analysis for Australia and New Zealand Bank')
# Out:
# Text(0.5, 1.0, 'Mone Carlo Analysis for Australia and New Zealand Bank')

# %%
runs = 10000

simulation = np.zeros(runs)
for run in range(runs):
    simulation[run] = stock_monte_carlo(start_price, days, mu, sigma)[days - 1]

# %%
q = np.percentile(simulation, 1)

plt.hist(simulation, bins = 200)

#starting price
plt.figtext(0.6,0.8, s = 'Start price: $%.2f' %start_price)

#mean ending price
plt.figtext(0.6,0.7, s = 'Mean final price: $%.2f' %simulation.mean())

#variance of the price (within 99% confidence interval)
plt.figtext(0.6,0.6, s = 'Var(0.99) price: $%.2f' %(start_price - q))

#Display 1% quantile
plt.figtext(0.15,0.8, s = 'q(0.99): $%.2f' %q)

# Plot a line at the 1% quantile result
plt.axvline(x=q, linewidth = 4, color = 'r')

#title
plt.title(u"Final price distribution for Australia and New Zealand Bank Stock after %s days" % days, weight = 'bold');

# %%
mu = rets.mean()['WBC']
sigma = rets.std()['WBC']

start_price = 17.92

for run in range(100):
    plt.plot(stock_monte_carlo(start_price, days, mu, sigma))

plt.xlabel('Days')
plt.ylabel('Price')
plt.title('Mone Carlo Analysis for Westpac Banking Corporation')
# Out:
# Text(0.5, 1.0, 'Mone Carlo Analysis for Westpac Banking Corporation')

# %%
runs = 10000

simulation = np.zeros(runs)
for run in range(runs):
    simulation[run] = stock_monte_carlo(start_price, days, mu, sigma)[days - 1]

# %%
q = np.percentile(simulation, 1)

plt.hist(simulation, bins = 200)

#starting price
plt.figtext(0.6,0.8, s = 'Start price: $%.2f' %start_price)

#mean ending price
plt.figtext(0.6,0.7, s = 'Mean final price: $%.2f' %simulation.mean())

#variance of the price (within 99% confidence interval)
plt.figtext(0.6,0.6, s = 'Var(0.99) price: $%.2f' %(start_price - q))

#Display 1% quantile
plt.figtext(0.15,0.8, s = 'q(0.99): $%.2f' %q)

# Plot a line at the 1% quantile result
plt.axvline(x=q, linewidth = 4, color = 'r')

#title
plt.title(u"Final price distribution for Australia and New Zealand Bank Stock after %s days" % days, weight = 'bold')
# Out:
# Text(0.5, 1.0, 'Final price distribution for Australia and New Zealand Bank Stock after 365 days')

# %%
mu = rets.mean()['NAB']
sigma = rets.std()['NAB']

start_price = 18.10

for run in range(100):
    plt.plot(stock_monte_carlo(start_price, days, mu, sigma))

plt.xlabel('Days')
plt.ylabel('Price')
plt.title('Mone Carlo Analysis for National Australia Bank')
# Out:
# Text(0.5, 1.0, 'Mone Carlo Analysis for National Australia Bank')

# %%
runs = 10000

simulation = np.zeros(runs)
for run in range(runs):
    simulation[run] = stock_monte_carlo(start_price, days, mu, sigma)[days - 1]

# %%
q = np.percentile(simulation, 1)

plt.hist(simulation, bins = 200)

#starting price
plt.figtext(0.6,0.8, s = 'Start price: $%.2f' %start_price)

#mean ending price
plt.figtext(0.6,0.7, s = 'Mean final price: $%.2f' %simulation.mean())

#variance of the price (within 99% confidence interval)
plt.figtext(0.6,0.6, s = 'Var(0.99) price: $%.2f' %(start_price - q))

#Display 1% quantile
plt.figtext(0.15,0.8, s = 'q(0.99): $%.2f' %q)

# Plot a line at the 1% quantile result
plt.axvline(x=q, linewidth = 4, color = 'r')

#title
plt.title(u"Final price distribution for National Australia Bank Stock after %s days" % days, weight = 'bold')
# Out:
# Text(0.5, 1.0, 'Final price distribution for National Australia Bank Stock after 365 days')
